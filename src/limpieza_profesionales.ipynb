# %% [markdown]
# # Limpieza dataset de profesionales
#
# En el presente archivo se realiza la limpieza de los datos que no terminaron de salir limpios en el scrapeo.

# %%
# Importación de librerías y recursos

# %%
import numpy as np
import pandas as pd
import time

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de la librería pymongo para recuperar los datos ubicados en MongoDB

# %%
from pymongo import MongoClient
cursor=MongoClient()
final_proj = cursor.lol_scouting                                                   
colec = final_proj.player_prof

# %%
data = [e for e in colec.find()]

# %%
df = pd.DataFrame(data)

df.head()
# Out:
#                         _id nombre_invocador region         liga  lps  \
# 0  640d83d1b40cd7e943808789    100T Bjergsen     NA     Diamante
# 1  640d83d27177991764ba4b71     Hide on bush     KR  GrandMaster  542
# 2  640d83d2c0978a14433e3289    Jinno Kingdom    EUW   Challenger  801
# 3  640d83d52e0f5469d90e15b9    Satoru Gojo03    EUW   Challenger  984
# 4  640d83e9c0978a14433e328a          LFT ADC    EUW     Diamante
#
#         cola ranking_mundial ranking_porcentaje wins loses n_games  \
# 0  Soloqueue          67,342          Top 0.71%   61    50     111
# 1  Soloqueue           4,736         Top 0.049%  149   135     284
# 2  Soloqueue           1,183         Top 0.012%  295   273     568
# 3  Soloqueue             535        Top 0.0056%   77    47     124
# 4  Soloqueue         211,267           Top 2.2%    7    13      20
#
#   winrate_total
# 0          55.0
# 1          52.5
# 2          51.9
# 3          62.1
# 4          35.0

# %%
# Eliminamos columnas de datos que no nos interesan, así como registros de los que no se han conseguido scrapear
# datos muy relevantes

# %%
df.drop('_id', axis = 1, inplace = True)

# %%
df.ranking_porcentaje = df.ranking_porcentaje.apply(lambda x: x.split(' ')[1][:-1])

# %%
df.ranking_mundial = df.ranking_mundial.apply(lambda x: x.replace(',', '') if ',' in x else x)

# %%
ind = df.loc[df['lps'] == ''].index

# %%
df.drop(index = ind, inplace = True)

# %%
# Transformación del tipo de dato

# %%
df.lps = df.lps.astype(int)
df.ranking_mundial = df.ranking_mundial.astype(int)
df.ranking_porcentaje = df.ranking_porcentaje.astype(float)
df.wins = df.wins.astype(int)
df.loses = df.loses.astype(int)
df.n_games = df.n_games.astype(int)
df.winrate_total = df.winrate_total.astype(float)

# %%
# Etiquetamos columna categórica para poder operar con ella en el futuro

# %%
df.liga.unique()
# Out:
# array(['GrandMaster', 'Challenger', 'Master'], dtype=object)

# %%
df['liga_label'] = df.liga.apply(lambda x: 2 if x == 'Challenger' else 1 if x == 'GrandMaster' else 0)

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 55
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nombre_invocador    51 non-null     object
#  1   region              51 non-null     object
#  2   liga                51 non-null     object
#  3   lps                 51 non-null     int64
#  4   cola                51 non-null     object
#  5   ranking_mundial     51 non-null     int64
#  6   ranking_porcentaje  51 non-null     float64
#  7   wins                51 non-null     int64
#  8   loses               51 non-null     int64
#  9   n_games             51 non-null     int64
#  10  winrate_total       51 non-null     float64
#  11  liga_label          51 non-null     int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 5.2+ KB

# %%
# Exportamos df limpio a .csv

# %%
df.to_csv('../data/info_general_prof.csv', index = False)

# %% [markdown]
# **DF_2**

# %%
# Seguiremos un proceso similar al anterior. 
# Recuperamos los datos de MongoDB, los limpiamos, transformamos el dato si se requiere y los exportamos a un .csv

# %%
colec = final_proj.rol_kda_profesional
data_2 = [e for e in colec.find()]

# %%
df_2 = pd.DataFrame(data_2)

df_2.head()
# Out:
#                         _id nombre invocador kills_player_kda  \
# 0  640dab79768ab9d1e7077311    100T Bjergsen              5.2
# 1  640dab802531c56df77b483a              NaN              6.6
# 2  640dab80c39dccc9f705d3b5              NaN              5.4
# 3  640dab806f2eedc2432669b0              NaN              7.2
# 4  640dab902531c56df77b483b              NaN              7.3
#
#   deaths_player_kda assists_player_kda     rol_1 games_per_rol_1  \
# 0               3.7                6.1       Mid              89
# 1               4.9                7.5  AD Carry             447
# 2               4.2                6.4       Mid             246
# 3               5.2                7.2  AD Carry             120
# 4               5.8                5.5  AD Carry              20
#
#   winrate_per_rol_1    rol_2 games_per_rol_2 winrate_per_rol_2  \
# 0              57.3      Top              22              45.5
# 1              53.7  Jungler              59              45.8
# 2              54.1  Jungler              25              44.0
# 3              61.7      Mid               3             100.0
# 4              35.0      NaN             NaN               NaN
#
#   nombre_invocador    rol_3 games_per_rol_3 winrate_per_rol_3
# 0              NaN      NaN             NaN               NaN
# 1    Jinno Kingdom  Support              37              51.4
# 2     Hide on bush      Top               8              37.5
# 3    Satoru Gojo03  Jungler               1               0.0
# 4          LFT ADC      NaN             NaN               NaN

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 56 non-null     object
#  1   nombre invocador    3 non-null      object
#  2   kills_player_kda    56 non-null     object
#  3   deaths_player_kda   56 non-null     object
#  4   assists_player_kda  56 non-null     object
#  5   rol_1               56 non-null     object
#  6   games_per_rol_1     56 non-null     object
#  7   winrate_per_rol_1   56 non-null     object
#  8   rol_2               55 non-null     object
#  9   games_per_rol_2     55 non-null     object
#  10  winrate_per_rol_2   55 non-null     object
#  11  nombre_invocador    53 non-null     object
#  12  rol_3               52 non-null     object
#  13  games_per_rol_3     52 non-null     object
#  14  winrate_per_rol_3   52 non-null     object
# dtypes: object(15)
# memory usage: 6.7+ KB

# %%
df_2.drop(['_id', 'nombre invocador'], axis = 1, inplace = True)

# %%
ind = df_2.loc[df_2['nombre_invocador'].isna()].index

# %%
df_2.drop(index = ind, inplace = True)

# %%
df_2 = df_2.fillna(0)

# %%
df_2.head()
# Out:
#   kills_player_kda deaths_player_kda assists_player_kda     rol_1  \
# 1              6.6               4.9                7.5  AD Carry
# 2              5.4               4.2                6.4       Mid
# 3              7.2               5.2                7.2  AD Carry
# 4              7.3               5.8                5.5  AD Carry
# 5              7.1               5.9                5.7       Top
#
#   games_per_rol_1 winrate_per_rol_1    rol_2 games_per_rol_2  \
# 1             447              53.7  Jungler              59
# 2             246              54.1  Jungler              25
# 3             120              61.7      Mid               3
# 4              20              35.0        0               0
# 5             189              60.8  Jungler               7
#
#   winrate_per_rol_2  nombre_invocador    rol_3 games_per_rol_3  \
# 1              45.8     Jinno Kingdom  Support              37
# 2              44.0      Hide on bush      Top               8
# 3             100.0     Satoru Gojo03  Jungler               1
# 4                 0           LFT ADC        0               0
# 5              42.9  Kongenvenderhjem      Mid               7
#
#   winrate_per_rol_3
# 1              51.4
# 2              37.5
# 3               0.0
# 4                 0
# 5              57.1

# %%
df_2.kills_player_kda = df_2.kills_player_kda.astype(float)
df_2.deaths_player_kda = df_2.deaths_player_kda.astype(float)
df_2.assists_player_kda = df_2.assists_player_kda.astype(float)
df_2.games_per_rol_1 = df_2.games_per_rol_1.astype(int)
df_2.winrate_per_rol_1 = df_2.winrate_per_rol_1.astype(float)

# %%
df_2.games_per_rol_2 = df_2.games_per_rol_2.astype(float)
df_2.winrate_per_rol_2 = df_2.winrate_per_rol_2.astype(float)
df_2.games_per_rol_3 = df_2.games_per_rol_3.astype(float)
df_2.winrate_per_rol_3 = df_2.winrate_per_rol_3.astype(float)

# %%
df_2.drop_duplicates(inplace = True)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 1 to 55
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kills_player_kda    53 non-null     float64
#  1   deaths_player_kda   53 non-null     float64
#  2   assists_player_kda  53 non-null     float64
#  3   rol_1               53 non-null     object
#  4   games_per_rol_1     53 non-null     int64
#  5   winrate_per_rol_1   53 non-null     float64
#  6   rol_2               53 non-null     object
#  7   games_per_rol_2     53 non-null     float64
#  8   winrate_per_rol_2   53 non-null     float64
#  9   nombre_invocador    53 non-null     object
#  10  rol_3               53 non-null     object
#  11  games_per_rol_3     53 non-null     float64
#  12  winrate_per_rol_3   53 non-null     float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 5.8+ KB

# %%
df_2.to_csv('../data/rol_kda_prof.csv', index = False)

# %% [markdown]
# **DF_3**

# %%
# Mismo proceso con el tercer y último df

# %%
colec = final_proj.champs_prof
data_3 = [e for e in colec.find()]

# %%
df_3 = pd.DataFrame(data_3)

df_3.head()
# Out:
#                         _id            nombre       champ_1 regional_rank_1  \
# 0  640db1e814ffaaa53732dc8b     Satoru Gojo03          Zeri      (EUW: 122)
# 1  640db206a39d37fbfeb367a8      Hide on bush         Annie       (KR: 514)
# 2  640db2084b1fd25546f0d2db     Jinno Kingdom         Varus      (EUW: 299)
# 3  640db214d33eb5cd2a1bf858  Kongenvenderhjem         Jayce       (EUW: 36)
# 4  640db320a39d37fbfeb367a9   pleroma chronou  Aurelion Sol      (EUW: 839)
#
#   kills_champ_1 deaths_champ_1 assists_champ_1 games_champ_1 winrate_champ_1  \
# 0           7.3            4.6             5.9            23            60.9
# 1           5.0            2.8             6.7            28            67.9
# 2           7.8            4.6             8.0            79            53.2
# 3           6.8            6.1             5.6            38            73.7
# 4           7.5            6.7             7.9            24            54.2
#
#         champ_2 regional_rank_2 kills_champ_2 deaths_champ_2 assists_champ_2  \
# 0        Draven             880           8.0            5.9             7.7
# 1  Aurelion Sol             245           6.9            3.4             6.6
# 2          Zeri              72           6.8            3.4             6.1
# 3     Gangplank   (EUW: 10,569)           7.0            5.7             6.3
# 4      Tristana           1,216           8.8            5.0             4.9
#
#   games_champ_2 winrate_champ_2  champ_3 regional_rank_3 kills_champ_3  \
# 0            21            57.1    Varus           1,558           6.8
# 1            27            55.6     Yone             850           5.1
# 2            64            64.1  Caitlyn              18           6.9
# 3            28            71.4    Fiora              53           5.0
# 4            22            63.6    Akali             756           9.8
#
#   deaths_champ_3 assists_champ_3 games_champ_3 winrate_champ_3   champ_4  \
# 0            5.8             8.2            17            58.8  Aphelios
# 1            4.5             5.4            16            62.5     Sylas
# 2            4.8             5.8            51            56.9    Ezreal
# 3            5.6             4.9            14            50.0  Vladimir
# 4            4.0             5.4            17            64.7     Sylas
#
#   regional_rank_4 kills_champ_4 deaths_champ_4 assists_champ_4 games_champ_4  \
# 0           1,905           6.0            5.4             7.4            17
# 1           1,640           4.4            3.8             5.4            16
# 2              97           7.3            5.6             6.6            36
# 3             305           4.3            5.0             5.4            11
# 4             831           7.5            4.8             4.9            15
#
#   winrate_champ_4  champ_5 regional_rank_5 kills_champ_5 deaths_champ_5  \
# 0            52.9  Caitlyn             666           5.8            4.5
# 1            50.0    Akali          19,442           7.9            3.9
# 2            52.8    Sivir             678           6.3            4.4
# 3            54.5     Gnar           2,672           8.1            4.2
# 4            53.3     Ryze           3,807           7.7            3.8
#
#   assists_champ_5 games_champ_5 winrate_champ_5  champ_6 regional_rank_6  \
# 0             7.7            13            61.5   Lucian           4,463
# 1             4.3            15            60.0     Ryze           1,667
# 2             8.8            32            62.5   Draven             106
# 3             5.3            10            70.0    Quinn           2,429
# 4             5.8            12            75.0  Lee Sin           1,546
#
#   kills_champ_6 deaths_champ_6 assists_champ_6 games_champ_6 winrate_champ_6  \
# 0           9.5            6.4             7.7            11            81.8
# 1           4.9            3.2             6.4            15            53.3
# 2           7.6            5.4             5.6            29            48.3
# 3           8.8            7.1             6.0            10            60.0
# 4           8.4            5.6             4.5            12            66.7
#
#     champ_7 regional_rank_7 kills_champ_7 deaths_champ_7 assists_champ_7  \
# 0     Xayah             210           8.4            2.8             6.4
# 1  Tristana           5,271           5.9            6.7             4.5
# 2    Maokai           1,391           3.6            4.3            10.4
# 3       Jax             485           4.2            5.9             4.3
# 4    Syndra                           6.4            5.2             8.8
#
#   games_champ_7 winrate_champ_7  champ_8 regional_rank_8 kills_champ_8  \
# 0             9            88.9    Sivir                           6.3
# 1            13            30.8    Jayce          18,688           5.8
# 2            25            56.0    Xayah           1,137           6.9
# 3             9            33.3  Lee Sin             540           9.3
# 4             9            55.6   Gragas                           2.3
#
#   deaths_champ_8 assists_champ_8 games_champ_8 winrate_champ_8
# 0            9.0            11.3             3            66.7
# 1            6.3             6.6            12            25.0
# 2            5.5             5.7            24            37.5
# 3            6.1             4.3             8            62.5
# 4            5.9             8.0             7            42.9

# %%
df_3.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 58 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              40 non-null     object
#  1   nombre           40 non-null     object
#  2   champ_1          40 non-null     object
#  3   regional_rank_1  40 non-null     object
#  4   kills_champ_1    40 non-null     object
#  5   deaths_champ_1   40 non-null     object
#  6   assists_champ_1  40 non-null     object
#  7   games_champ_1    40 non-null     object
#  8   winrate_champ_1  40 non-null     object
#  9   champ_2          40 non-null     object
#  10  regional_rank_2  40 non-null     object
#  11  kills_champ_2    40 non-null     object
#  12  deaths_champ_2   40 non-null     object
#  13  assists_champ_2  40 non-null     object
#  14  games_champ_2    40 non-null     object
#  15  winrate_champ_2  40 non-null     object
#  16  champ_3          40 non-null     object
#  17  regional_rank_3  40 non-null     object
#  18  kills_champ_3    40 non-null     object
#  19  deaths_champ_3   40 non-null     object
#  20  assists_champ_3  40 non-null     object
#  21  games_champ_3    40 non-null     object
#  22  winrate_champ_3  40 non-null     object
#  23  champ_4          40 non-null     object
#  24  regional_rank_4  40 non-null     object
#  25  kills_champ_4    40 non-null     object
#  26  deaths_champ_4   40 non-null     object
#  27  assists_champ_4  40 non-null     object
#  28  games_champ_4    40 non-null     object
#  29  winrate_champ_4  40 non-null     object
#  30  champ_5          40 non-null     object
#  31  regional_rank_5  40 non-null     object
#  32  kills_champ_5    40 non-null     object
#  33  deaths_champ_5   40 non-null     object
#  34  assists_champ_5  40 non-null     object
#  35  games_champ_5    40 non-null     object
#  36  winrate_champ_5  40 non-null     object
#  37  champ_6          40 non-null     object
#  38  regional_rank_6  40 non-null     object
#  39  kills_champ_6    40 non-null     object
#  40  deaths_champ_6   40 non-null     object
#  41  assists_champ_6  40 non-null     object
#  42  games_champ_6    40 non-null     object
#  43  winrate_champ_6  40 non-null     object
#  44  champ_7          40 non-null     object
#  45  regional_rank_7  40 non-null     object
#  46  kills_champ_7    40 non-null     object
#  47  deaths_champ_7   40 non-null     object
#  48  assists_champ_7  40 non-null     object
#  49  games_champ_7    40 non-null     object
#  50  winrate_champ_7  40 non-null     object
#  51  champ_8          40 non-null     object
#  52  regional_rank_8  40 non-null     object
#  53  kills_champ_8    40 non-null     object
#  54  deaths_champ_8   40 non-null     object
#  55  assists_champ_8  40 non-null     object
#  56  games_champ_8    40 non-null     object
#  57  winrate_champ_8  40 non-null     object
# dtypes: object(58)
# memory usage: 136.8 KB

# %%
df_3.drop('_id', axis = 1, inplace = True)

# %%
df_3.regional_rank_1 = df_3.regional_rank_1.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_2 = df_3.regional_rank_2.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_3 = df_3.regional_rank_3.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_4 = df_3.regional_rank_4.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_5 = df_3.regional_rank_5.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_6 = df_3.regional_rank_6.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_7 = df_3.regional_rank_7.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)
df_3.regional_rank_8 = df_3.regional_rank_8.apply(lambda x: x.split(' ')[1][:-1] if len(x.split(' ')) > 1 else x)

# %%
df_3.regional_rank_1 = df_3.regional_rank_1.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_2 = df_3.regional_rank_2.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_3 = df_3.regional_rank_3.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_4 = df_3.regional_rank_4.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_5 = df_3.regional_rank_5.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_6 = df_3.regional_rank_6.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_7 = df_3.regional_rank_7.apply(lambda x: x.replace(',', ''))
df_3.regional_rank_8 = df_3.regional_rank_8.apply(lambda x: x.replace(',', ''))

# %%
df_3.regional_rank_4 = df_3.regional_rank_4.apply(lambda x: x.replace('', '0') if x == '' else x)
df_3.regional_rank_5 = df_3.regional_rank_5.apply(lambda x: x.replace('', '0') if x == '' else x)
df_3.regional_rank_6 = df_3.regional_rank_6.apply(lambda x: x.replace('', '0') if x == '' else x)
df_3.regional_rank_7 = df_3.regional_rank_7.apply(lambda x: x.replace('', '0') if x == '' else x)
df_3.regional_rank_8 = df_3.regional_rank_8.apply(lambda x: x.replace('', '0') if x == '' else x)

# %%
df_3.regional_rank_1 = df_3.regional_rank_1.astype(int)
df_3.regional_rank_2 = df_3.regional_rank_2.astype(int)
df_3.regional_rank_3 = df_3.regional_rank_3.astype(int)
df_3.regional_rank_4 = df_3.regional_rank_4.astype(int)
df_3.regional_rank_5 = df_3.regional_rank_5.astype(int)
df_3.regional_rank_6 = df_3.regional_rank_6.astype(int)
df_3.regional_rank_7 = df_3.regional_rank_7.astype(int)
df_3.regional_rank_8 = df_3.regional_rank_8.astype(int)

# %%
df_3.kills_champ_1 = df_3.kills_champ_1.astype(float)
df_3.kills_champ_2 = df_3.kills_champ_2.astype(float)
df_3.kills_champ_3 = df_3.kills_champ_3.astype(float)
df_3.kills_champ_4 = df_3.kills_champ_4.astype(float)
df_3.kills_champ_5 = df_3.kills_champ_5.astype(float)
df_3.kills_champ_6 = df_3.kills_champ_6.astype(float)
df_3.kills_champ_7 = df_3.kills_champ_7.astype(float)
df_3.kills_champ_8 = df_3.kills_champ_8.astype(float)

# %%
df_3.deaths_champ_1 = df_3.deaths_champ_1.astype(float)
df_3.deaths_champ_2 = df_3.deaths_champ_2.astype(float)
df_3.deaths_champ_3 = df_3.deaths_champ_3.astype(float)
df_3.deaths_champ_4 = df_3.deaths_champ_4.astype(float)
df_3.deaths_champ_5 = df_3.deaths_champ_5.astype(float)
df_3.deaths_champ_6 = df_3.deaths_champ_6.astype(float)
df_3.deaths_champ_7 = df_3.deaths_champ_7.astype(float)
df_3.deaths_champ_8 = df_3.deaths_champ_8.astype(float)

# %%
df_3.assists_champ_1 = df_3.assists_champ_1.astype(float)
df_3.assists_champ_2 = df_3.assists_champ_2.astype(float)
df_3.assists_champ_3 = df_3.assists_champ_3.astype(float)
df_3.assists_champ_4 = df_3.assists_champ_4.astype(float)
df_3.assists_champ_5 = df_3.assists_champ_5.astype(float)
df_3.assists_champ_6 = df_3.assists_champ_6.astype(float)
df_3.assists_champ_7 = df_3.assists_champ_7.astype(float)
df_3.assists_champ_8 = df_3.assists_champ_8.astype(float)

# %%
df_3.games_champ_3 = df_3.games_champ_3.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)
df_3.games_champ_4 = df_3.games_champ_4.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)
df_3.games_champ_5 = df_3.games_champ_5.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)
df_3.games_champ_6 = df_3.games_champ_6.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)
df_3.games_champ_7 = df_3.games_champ_7.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)
df_3.games_champ_8 = df_3.games_champ_8.apply(lambda x: x.split('.')[0][1:] if '%' in x else x)

# %%
df_3.games_champ_1 = df_3.games_champ_1.astype(int)
df_3.games_champ_2 = df_3.games_champ_2.astype(int)
df_3.games_champ_3 = df_3.games_champ_3.astype(int)
df_3.games_champ_4 = df_3.games_champ_4.astype(int)
df_3.games_champ_5 = df_3.games_champ_5.astype(int)
df_3.games_champ_6 = df_3.games_champ_6.astype(int)
df_3.games_champ_7 = df_3.games_champ_7.astype(int)
df_3.games_champ_8 = df_3.games_champ_8.astype(int)

# %%
df_3.winrate_champ_1 = df_3.winrate_champ_1.astype(float)
df_3.winrate_champ_2 = df_3.winrate_champ_2.astype(float)
df_3.winrate_champ_3 = df_3.winrate_champ_3.astype(float)
df_3.winrate_champ_4 = df_3.winrate_champ_4.astype(float)
df_3.winrate_champ_5 = df_3.winrate_champ_5.astype(float)
df_3.winrate_champ_6 = df_3.winrate_champ_6.astype(float)
df_3.winrate_champ_7 = df_3.winrate_champ_7.astype(float)
df_3.winrate_champ_8 = df_3.winrate_champ_8.astype(float)

# %%
df_3.drop_duplicates(inplace = True)

# %%
df_3.head()
# Out:
#              nombre       champ_1  regional_rank_1  kills_champ_1  \
# 0     Satoru Gojo03          Zeri              122            7.3
# 1      Hide on bush         Annie              514            5.0
# 2     Jinno Kingdom         Varus              299            7.8
# 3  Kongenvenderhjem         Jayce               36            6.8
# 4   pleroma chronou  Aurelion Sol              839            7.5
#
#    deaths_champ_1  assists_champ_1  games_champ_1  winrate_champ_1  \
# 0             4.6              5.9             23             60.9
# 1             2.8              6.7             28             67.9
# 2             4.6              8.0             79             53.2
# 3             6.1              5.6             38             73.7
# 4             6.7              7.9             24             54.2
#
#         champ_2  regional_rank_2  kills_champ_2  deaths_champ_2  \
# 0        Draven              880            8.0             5.9
# 1  Aurelion Sol              245            6.9             3.4
# 2          Zeri               72            6.8             3.4
# 3     Gangplank            10569            7.0             5.7
# 4      Tristana             1216            8.8             5.0
#
#    assists_champ_2  games_champ_2  winrate_champ_2  champ_3  regional_rank_3  \
# 0              7.7             21             57.1    Varus             1558
# 1              6.6             27             55.6     Yone              850
# 2              6.1             64             64.1  Caitlyn               18
# 3              6.3             28             71.4    Fiora               53
# 4              4.9             22             63.6    Akali              756
#
#    kills_champ_3  deaths_champ_3  assists_champ_3  games_champ_3  \
# 0            6.8             5.8              8.2             17
# 1            5.1             4.5              5.4             16
# 2            6.9             4.8              5.8             51
# 3            5.0             5.6              4.9             14
# 4            9.8             4.0              5.4             17
#
#    winrate_champ_3   champ_4  regional_rank_4  kills_champ_4  deaths_champ_4  \
# 0             58.8  Aphelios             1905            6.0             5.4
# 1             62.5     Sylas             1640            4.4             3.8
# 2             56.9    Ezreal               97            7.3             5.6
# 3             50.0  Vladimir              305            4.3             5.0
# 4             64.7     Sylas              831            7.5             4.8
#
#    assists_champ_4  games_champ_4  winrate_champ_4  champ_5  regional_rank_5  \
# 0              7.4             17             52.9  Caitlyn              666
# 1              5.4             16             50.0    Akali            19442
# 2              6.6             36             52.8    Sivir              678
# 3              5.4             11             54.5     Gnar             2672
# 4              4.9             15             53.3     Ryze             3807
#
#    kills_champ_5  deaths_champ_5  assists_champ_5  games_champ_5  \
# 0            5.8             4.5              7.7             13
# 1            7.9             3.9              4.3             15
# 2            6.3             4.4              8.8             32
# 3            8.1             4.2              5.3             10
# 4            7.7             3.8              5.8             12
#
#    winrate_champ_5  champ_6  regional_rank_6  kills_champ_6  deaths_champ_6  \
# 0             61.5   Lucian             4463            9.5             6.4
# 1             60.0     Ryze             1667            4.9             3.2
# 2             62.5   Draven              106            7.6             5.4
# 3             70.0    Quinn             2429            8.8             7.1
# 4             75.0  Lee Sin             1546            8.4             5.6
#
#    assists_champ_6  games_champ_6  winrate_champ_6   champ_7  regional_rank_7  \
# 0              7.7             11             81.8     Xayah              210
# 1              6.4             15             53.3  Tristana             5271
# 2              5.6             29             48.3    Maokai             1391
# 3              6.0             10             60.0       Jax              485
# 4              4.5             12             66.7    Syndra                0
#
#    kills_champ_7  deaths_champ_7  assists_champ_7  games_champ_7  \
# 0            8.4             2.8              6.4              9
# 1            5.9             6.7              4.5             13
# 2            3.6             4.3             10.4             25
# 3            4.2             5.9              4.3              9
# 4            6.4             5.2              8.8              9
#
#    winrate_champ_7  champ_8  regional_rank_8  kills_champ_8  deaths_champ_8  \
# 0             88.9    Sivir                0            6.3             9.0
# 1             30.8    Jayce            18688            5.8             6.3
# 2             56.0    Xayah             1137            6.9             5.5
# 3             33.3  Lee Sin              540            9.3             6.1
# 4             55.6   Gragas                0            2.3             5.9
#
#    assists_champ_8  games_champ_8  winrate_champ_8
# 0             11.3              3             66.7
# 1              6.6             12             25.0
# 2              5.7             24             37.5
# 3              4.3              8             62.5
# 4              8.0              7             42.9

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 39
# Data columns (total 57 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre           40 non-null     object
#  1   champ_1          40 non-null     object
#  2   regional_rank_1  40 non-null     int64
#  3   kills_champ_1    40 non-null     float64
#  4   deaths_champ_1   40 non-null     float64
#  5   assists_champ_1  40 non-null     float64
#  6   games_champ_1    40 non-null     int64
#  7   winrate_champ_1  40 non-null     float64
#  8   champ_2          40 non-null     object
#  9   regional_rank_2  40 non-null     int64
#  10  kills_champ_2    40 non-null     float64
#  11  deaths_champ_2   40 non-null     float64
#  12  assists_champ_2  40 non-null     float64
#  13  games_champ_2    40 non-null     int64
#  14  winrate_champ_2  40 non-null     float64
#  15  champ_3          40 non-null     object
#  16  regional_rank_3  40 non-null     int64
#  17  kills_champ_3    40 non-null     float64
#  18  deaths_champ_3   40 non-null     float64
#  19  assists_champ_3  40 non-null     float64
#  20  games_champ_3    40 non-null     int64
#  21  winrate_champ_3  40 non-null     float64
#  22  champ_4          40 non-null     object
#  23  regional_rank_4  40 non-null     int64
#  24  kills_champ_4    40 non-null     float64
#  25  deaths_champ_4   40 non-null     float64
#  26  assists_champ_4  40 non-null     float64
#  27  games_champ_4    40 non-null     int64
#  28  winrate_champ_4  40 non-null     float64
#  29  champ_5          40 non-null     object
#  30  regional_rank_5  40 non-null     int64
#  31  kills_champ_5    40 non-null     float64
#  32  deaths_champ_5   40 non-null     float64
#  33  assists_champ_5  40 non-null     float64
#  34  games_champ_5    40 non-null     int64
#  35  winrate_champ_5  40 non-null     float64
#  36  champ_6          40 non-null     object
#  37  regional_rank_6  40 non-null     int64
#  38  kills_champ_6    40 non-null     float64
#  39  deaths_champ_6   40 non-null     float64
#  40  assists_champ_6  40 non-null     float64
#  41  games_champ_6    40 non-null     int64
#  42  winrate_champ_6  40 non-null     float64
#  43  champ_7          40 non-null     object
#  44  regional_rank_7  40 non-null     int64
#  45  kills_champ_7    40 non-null     float64
#  46  deaths_champ_7   40 non-null     float64
#  47  assists_champ_7  40 non-null     float64
#  48  games_champ_7    40 non-null     int64
#  49  winrate_champ_7  40 non-null     float64
#  50  champ_8          40 non-null     object
#  51  regional_rank_8  40 non-null     int64
#  52  kills_champ_8    40 non-null     float64
#  53  deaths_champ_8   40 non-null     float64
#  54  assists_champ_8  40 non-null     float64
#  55  games_champ_8    40 non-null     int64
#  56  winrate_champ_8  40 non-null     float64
# dtypes: float64(32), int64(16), object(9)
# memory usage: 18.1+ KB

# %%
df_3.rename(columns={'nombre': 'nombre_invocador'}, inplace = True)

# %%
df_3.to_csv('../data/champs_stats_prof.csv', index = False)

# %% [markdown]
# **MERGEANDO DFs**

# %%
# Una vez limpios nuestros 3 dfs, hacemos merge para tener centralizada toda la info en un solo df

# %%
merg = pd.merge(df, df_2, on = 'nombre_invocador')

# %%
merg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 48
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nombre_invocador    49 non-null     object
#  1   region              49 non-null     object
#  2   liga                49 non-null     object
#  3   lps                 49 non-null     int64
#  4   cola                49 non-null     object
#  5   ranking_mundial     49 non-null     int64
#  6   ranking_porcentaje  49 non-null     float64
#  7   wins                49 non-null     int64
#  8   loses               49 non-null     int64
#  9   n_games             49 non-null     int64
#  10  winrate_total       49 non-null     float64
#  11  liga_label          49 non-null     int64
#  12  kills_player_kda    49 non-null     float64
#  13  deaths_player_kda   49 non-null     float64
#  14  assists_player_kda  49 non-null     float64
#  15  rol_1               49 non-null     object
#  16  games_per_rol_1     49 non-null     int64
#  17  winrate_per_rol_1   49 non-null     float64
#  18  rol_2               49 non-null     object
#  19  games_per_rol_2     49 non-null     float64
#  20  winrate_per_rol_2   49 non-null     float64
#  21  rol_3               49 non-null     object
#  22  games_per_rol_3     49 non-null     float64
#  23  winrate_per_rol_3   49 non-null     float64
# dtypes: float64(10), int64(7), object(7)
# memory usage: 9.6+ KB

# %%
bd = pd.merge(merg, df_3, on = 'nombre_invocador')

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 37
# Data columns (total 80 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nombre_invocador    38 non-null     object
#  1   region              38 non-null     object
#  2   liga                38 non-null     object
#  3   lps                 38 non-null     int64
#  4   cola                38 non-null     object
#  5   ranking_mundial     38 non-null     int64
#  6   ranking_porcentaje  38 non-null     float64
#  7   wins                38 non-null     int64
#  8   loses               38 non-null     int64
#  9   n_games             38 non-null     int64
#  10  winrate_total       38 non-null     float64
#  11  liga_label          38 non-null     int64
#  12  kills_player_kda    38 non-null     float64
#  13  deaths_player_kda   38 non-null     float64
#  14  assists_player_kda  38 non-null     float64
#  15  rol_1               38 non-null     object
#  16  games_per_rol_1     38 non-null     int64
#  17  winrate_per_rol_1   38 non-null     float64
#  18  rol_2               38 non-null     object
#  19  games_per_rol_2     38 non-null     float64
#  20  winrate_per_rol_2   38 non-null     float64
#  21  rol_3               38 non-null     object
#  22  games_per_rol_3     38 non-null     float64
#  23  winrate_per_rol_3   38 non-null     float64
#  24  champ_1             38 non-null     object
#  25  regional_rank_1     38 non-null     int64
#  26  kills_champ_1       38 non-null     float64
#  27  deaths_champ_1      38 non-null     float64
#  28  assists_champ_1     38 non-null     float64
#  29  games_champ_1       38 non-null     int64
#  30  winrate_champ_1     38 non-null     float64
#  31  champ_2             38 non-null     object
#  32  regional_rank_2     38 non-null     int64
#  33  kills_champ_2       38 non-null     float64
#  34  deaths_champ_2      38 non-null     float64
#  35  assists_champ_2     38 non-null     float64
#  36  games_champ_2       38 non-null     int64
#  37  winrate_champ_2     38 non-null     float64
#  38  champ_3             38 non-null     object
#  39  regional_rank_3     38 non-null     int64
#  40  kills_champ_3       38 non-null     float64
#  41  deaths_champ_3      38 non-null     float64
#  42  assists_champ_3     38 non-null     float64
#  43  games_champ_3       38 non-null     int64
#  44  winrate_champ_3     38 non-null     float64
#  45  champ_4             38 non-null     object
#  46  regional_rank_4     38 non-null     int64
#  47  kills_champ_4       38 non-null     float64
#  48  deaths_champ_4      38 non-null     float64
#  49  assists_champ_4     38 non-null     float64
#  50  games_champ_4       38 non-null     int64
#  51  winrate_champ_4     38 non-null     float64
#  52  champ_5             38 non-null     object
#  53  regional_rank_5     38 non-null     int64
#  54  kills_champ_5       38 non-null     float64
#  55  deaths_champ_5      38 non-null     float64
#  56  assists_champ_5     38 non-null     float64
#  57  games_champ_5       38 non-null     int64
#  58  winrate_champ_5     38 non-null     float64
#  59  champ_6             38 non-null     object
#  60  regional_rank_6     38 non-null     int64
#  61  kills_champ_6       38 non-null     float64
#  62  deaths_champ_6      38 non-null     float64
#  63  assists_champ_6     38 non-null     float64
#  64  games_champ_6       38 non-null     int64
#  65  winrate_champ_6     38 non-null     float64
#  66  champ_7             38 non-null     object
#  67  regional_rank_7     38 non-null     int64
#  68  kills_champ_7       38 non-null     float64
#  69  deaths_champ_7      38 non-null     float64
#  70  assists_champ_7     38 non-null     float64
#  71  games_champ_7       38 non-null     int64
#  72  winrate_champ_7     38 non-null     float64
#  73  champ_8             38 non-null     object
#  74  regional_rank_8     38 non-null     int64
#  75  kills_champ_8       38 non-null     float64
#  76  deaths_champ_8      38 non-null     float64
#  77  assists_champ_8     38 non-null     float64
#  78  games_champ_8       38 non-null     int64
#  79  winrate_champ_8     38 non-null     float64
# dtypes: float64(42), int64(23), object(15)
# memory usage: 24.0+ KB

# %%
bd.rol_1.value_counts()
# Out:
# Mid         10
# Support      9
# Jungler      8
# AD Carry     6
# Top          5
# Name: rol_1, dtype: int64

# %%
bd['nivel'] = 'profesional'

# %%
bd.to_csv('../data/total_prof.csv', index = False)
